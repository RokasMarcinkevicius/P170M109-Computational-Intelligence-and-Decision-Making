# %%
Mobile Application for Landmark Identification
    An app that, when pointed at a building or location, recognizes it in real time, links it to Wikipedia information, and presents a short description with a reference link.


1. Mobile Front End:
- Flutter/Android Studio - Arda Erdogan


2. Back End/SQL:
- .NET C# - 5 years - Rokas / Python

Teoman -
Mariia - Full stack/front end - React / Java
Santhosh -

API to chat gpt/azure/local llm
We can also look for pre-trained models (azure)
We need to find a large/good data set for training

1. Goal is to recognize image - get location? train on monuments, do we need to go into the maps?
2. Working AI model (training)
Maybe use wikipedia page or prepared data set

Related medium article = https://medium.com/@panditsiddhant.sp_78380/a-machine-learning-approach-to-geoguessr-style-location-prediction-0a5dffc1179e


Datasets for model training:

5 million images 200000 landmarks
https://github.com/cvdfoundation/google-landmark?tab=readme-ov-file

landmarks
https://www.kaggle.com/datasets/kayvanshah/landmarks-dataset

Google street view data set - https://www.kaggle.com/datasets/paulchambaz/google-street-view


Project description:
1. Image uploading, classification
1.1. gps data
1.2 image metadata:
1.2.1 longitude
1.2.2 latitude
image conversion - what plants are around/road
YOLO model - can find monument in the images
2. Get values from images

3. Feed into our model

4. Result - monument name and/or the coordinates/gps
4.1 if we only have coordinates then we need to search google or similar source for the coordinates and get the name
5. Cross reference wikipedia or similar source
6. Present short description with reference link
